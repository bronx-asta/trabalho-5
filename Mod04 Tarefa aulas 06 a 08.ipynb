# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui

url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

df = requests.get(url)
df = df.json()
dados = pd.DataFrame(df['items'])

rio = (dados['interessado'] == 'Rio de Janeiro')
rio = dados[rio]
rio
# Out:
#       id_pleito tipo_interessado     interessado  cod_ibge  uf  \
# 288       28489        Município  Rio de Janeiro   3304557  RJ
# 757        5470        Município  Rio de Janeiro   3304557  RJ
# 877        9452        Município  Rio de Janeiro   3304557  RJ
# 1103       5763        Município  Rio de Janeiro   3304557  RJ
# 1108       5630           Estado  Rio de Janeiro        33  RJ
# 1109       5635           Estado  Rio de Janeiro        33  RJ
# 1110       5640           Estado  Rio de Janeiro        33  RJ
# 1452      65245        Município  Rio de Janeiro   3304557  RJ
# 1482      27100        Município  Rio de Janeiro   3304557  RJ
# 1617       9664        Município  Rio de Janeiro   3304557  RJ
# 1821      13560           Estado  Rio de Janeiro        33  RJ
# 2540      13364           Estado  Rio de Janeiro        33  RJ
# 2654      10562           Estado  Rio de Janeiro        33  RJ
# 2656      12375           Estado  Rio de Janeiro        33  RJ
# ...

# %%
# 2) Seu código aqui
media = rio['status'].value_counts()
media
# Out:
# status
# Deferido                                                 7
# Encaminhado à PGFN com manifestação técnica favorável    7
# Arquivado por decurso de prazo                           2
# Arquivado                                                1
# Arquivado a pedido                                       1
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
data = str(rio['data_status'])
convertido = data.split()
print(convertido)
# Out:
# ['288', '22/10/2019', '757', '19/11/2010', '877', '09/02/2010', '1103', '25/04/2013', '1108', '21/11/2013', '1109', '06/05/2013', '1110', '29/07/2013', '1452', '03/08/2023', '1482', '07/01/2019', '1617', '12/05/2011', '1821', '27/06/2002', '2540', '22/05/2009', '2654', '27/12/2013', '2656', '27/12/2011', '2976', '13/07/2010', '3343', '29/11/2018', '4351', '28/12/2016', '4797', '01/09/2016', 'Name:', 'data_status,', 'dtype:', 'object']

# %%
# 3) Seu código aqui
rio['data_status'].value_counts()
# Out:
# data_status
# 22/10/2019    1
# 19/11/2010    1
# 28/12/2016    1
# 29/11/2018    1
# 13/07/2010    1
# 27/12/2011    1
# 27/12/2013    1
# 22/05/2009    1
# 27/06/2002    1
# 12/05/2011    1
# 07/01/2019    1
# 03/08/2023    1
# 29/07/2013    1
# 06/05/2013    1
# 21/11/2013    1
# 25/04/2013    1
# 09/02/2010    1
# 01/09/2016    1
# Name: count, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui
uf = pd.DataFrame(dados[['uf', 'tipo_interessado']])
uf
# Out:
#       uf tipo_interessado
# 0     SC        Município
# 1     MG        Município
# 2     SP        Município
# 3     SP        Município
# 4     MG        Município
# ...   ..              ...
# 4995  RS        Município
# 4996  PR        Município
# 4997  PR        Município
# 4998  SC        Município
# 4999  MG        Município
#
# [5000 rows x 2 columns]

# %%
# 2) Seu código aqui

minas = dados[dados['interessado'] == 'Minas Gerais'].status.value_counts()
minas
# Out:
# status
# Encaminhado à PGFN com manifestação técnica favorável    5
# Deferido                                                 1
# Arquivado a pedido                                       1
# Name: count, dtype: int64

# %%
# 3) Seu código aqui
bahia = (dados['uf'] == 'BA') & (dados['tipo_interessado'] == 'Município') & (dados['interessado'])
defe = (dados[bahia] == 'Deferido')
dados[defe].status.value_counts()
# Out:
# status
# Deferido    71
# Name: count, dtype: int64

# %%
# 4) Seu código aqui
es_ba = (dados['interessado'] == 'Bahia')
dados[es_ba].to_csv('bahia_estado.csv')
